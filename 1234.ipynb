# %%
import torch
from pathlib import Path

ckpt_path = Path(r"D:\ML3\checkpoints_finetune\finetune_resnet50_epoch_120.pt")
ckpt = torch.load(ckpt_path, map_location="cpu")

print("epoch:", ckpt.get("epoch"))
print("best_acc:", ckpt.get("best_acc"))
print("mode:", ckpt.get("mode"))
print("args:")
for k, v in ckpt.get("args", {}).items():
    if "finetune" in k or "proj" in k or "arch" in k or "lr" in k:
        print(k, "=", v)
# Out:
# epoch: 120
# best_acc: 82.65
# mode: finetune
# args:
# arch = resnet50
# lr = 0.02
# min_lr = 0.0
# proj_dim = 128
# proj_hidden_dim = 0
# proj_layers = 3
# finetune_proj_layers = 0
# ...
